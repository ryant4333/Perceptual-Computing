# %% [markdown]
# # Hough Lines

# %% [markdown]
# ### Import resources and display the image

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %matplotlib inline

# Read in the image
image = cv2.imread('images/phone.jpg')

# Change color to RGB (from BGR)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image)

# %% [markdown]
# ### Perform edge detection

# %%
# Convert image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

# Define our parameters for Canny
low_threshold = 50
high_threshold = 150
edges = cv2.Canny(gray, low_threshold, high_threshold)

plt.imshow(edges, cmap='gray')

# %% [markdown]
# ### Find lines using a Hough transform

# %%
line_image = np.copy(image) #creating an image copy to draw lines on

## TODO
# Define the Hough transform parameters
rho = 2
theta = np.pi/180
threshold = 50
min_line_length = 10
max_line_gap = 20

# Run Hough on the edge-detected image, get coordinates of lines
lines = cv2.HoughLinesP( edges, rho, theta, threshold,  np.array([]), 10, 20)
# Iterate over the output "lines" and draw lines on the image copy

for line in lines:
    for x1,y1,x2,y2 in line:
        cv2.line(line_image,(x1,y1),(x2,y2),(255,255,255),5)
        
plt.imshow(line_image)

## TODO
#Try line detection on different images

# %%
city_hall = cv2.imread("images\city_hall.jpg")
city_hall = cv2.cvtColor(city_hall, cv2.COLOR_BGR2RGB)
plt.imshow(city_hall)

# %%
gray_hall = cv2.cvtColor(city_hall, cv2.COLOR_RGB2GRAY)

# Define our parameters for Canny
low_threshold_hall = 190
high_threshold_hall = 200
edges_hall = cv2.Canny(gray_hall, low_threshold_hall, high_threshold_hall)

plt.imshow(edges_hall, cmap='gray')

# %%
hall_image = np.copy(city_hall) #creating an image copy to draw lines on

# Define the Hough transform parameters
rho = 1
theta = np.pi/180
threshold = 200
min_line_length = 100
max_line_gap = 5

# Run Hough on the edge-detected image, get coordinates of lines
hall_lines = cv2.HoughLinesP( edges_hall, rho, theta, threshold,  np.array([]), min_line_length, max_line_gap)
# Iterate over the output "lines" and draw lines on the image copy

for line in hall_lines:
    for x1,y1,x2,y2 in line:
        cv2.line(hall_image,(x1,y1),(x2,y2),(255,255,255),5)
        
plt.imshow(hall_image)
